# %%
import pandas as pd
import numpy as np
import networkx as nx

# Load the Excel file using forward slashes in the file path
df = pd.read_excel('25-Node_Network_Traffic_Flow.xlsx', header=0, index_col=0)
print(df.head())
df.index   = df.index.map(str)
df.columns = df.columns.map(str)
f_q = df.transpose()
network = {
    '1': {'2': 4, '5': 5},
    '2': {'1': 4, '4': 4, '3': 3},
    '3': {'9': 4, '4': 4, '2': 3},
    '4': {'9': 7, '3': 4, '2': 4, '5': 3, '7': 5, '8': 5},
    '5': {'1': 5, '4': 3, '7': 5, '6': 5},
    '6': {'5': 5, '7': 3},
    '7': {'4': 5, '5': 5, '6': 3, '12': 9, '11': 8, '8': 3},
    '8': {'4': 5, '7': 3, '11': 7, '13': 7, '10': 6, '9': 6},
    '9': {'3': 4, '4': 7, '8': 6, '10': 6},
    '10': {'9': 6, '8': 6, '13': 6, '14': 3},
    '11': {'7': 8, '12': 2, '16': 7, '13': 3, '8': 7},
    '12': {'7': 9, '11': 2, '16': 4, '15': 4},
    '13': {'8': 7, '11': 3, '19': 4, '14': 7, '10': 6},
    '14': {'10': 3, '13': 7, '19': 7, '21': 2, '22': 4},
    '15': {'16': 4, '12': 4},
    '16': {'12': 4, '15': 4, '17': 4, '11': 7},
    '17': {'16': 4, '18': 3, '19': 3},
    '18': {'17': 3, '20': 3},
    '19': {'13': 4, '17': 3, '20': 3, '14': 7},
    '20': {'18': 3, '19': 3, '21': 2},
    '21': {'14': 2, '20': 2},
    '22': {'14': 4, '23': 3},
    '23': {'22': 3, '24': 3},
    '24': {'23': 3, '25': 8},
    '25': {'24': 8},
}
